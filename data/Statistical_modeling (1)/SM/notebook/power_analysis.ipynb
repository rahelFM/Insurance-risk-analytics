# %%
# Import necessary libraries
import numpy as npRequired sample size per group: 64.0

import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
# Parameters for power analysis
effect_size = 0.5  # Medium effect size (Cohen's d)
alpha = 0.05       # Significance level
power = 0.80       # Desired power

# Calculate the required sample size
required_n = sm.stats.tt_ind_solve_power(effect_size=effect_size, 
                                           alpha=alpha, 
                                           power=power, 
                                           alternative='two-sided')
Required sample size per group: 64.0

print(f"Required sample size per group: {np.ceil(required_n)}")
print(f"Total required sample size: {np.ceil(required_n) * 2}")
# Out:
# Required sample size per group: 64.0
# Total required sample size: 128.0

# %%
# Parameters for power analysis
effect_size = 0.5  # Medium effect size (Cohen's d)
alpha = 0.05       # Significance level
sample_size = 64   # Sample size per group

# Calculate the power of the test
power = sm.stats.tt_ind_solve_power(effect_size=effect_size, 
                                     alpha=alpha, 
                                     nobs1=sample_size, 
                                     alternative='two-sided')

print(f"Calculated power of the test: {power:.4f}")
# Out:
# Calculated power of the test: 0.8015
